# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('E:/DataSets/covid_19_india.csv')

# %%
data.drop(['Time' , 'State/UnionTerritory','ConfirmedIndianNational','ConfirmedForeignNational'] , axis = 1 , inplace = True)

# %%
data.head()
# Out:
#    Sno      Date  Cured  Deaths  Confirmed
# 0    1  30/01/20      0       0          1
# 1    2  31/01/20      0       0          1
# 2    3  01/02/20      0       0          2
# 3    4  02/02/20      0       0          3
# 4    5  03/02/20      0       0          3

# %%
data =  data.groupby(data['Date']).sum()

# %%
data.to_csv('E:/anil.csv')

# %%
cd = pd.read_csv('E:/anil.csv')

# %%
cd['date'] = pd.to_datetime(cd.Date)

# %%
cd.drop(['Date' , 'Sno'] , axis = 1 , inplace = True)

# %%
df1 = cd.iloc[:36 , :]

# %%
df = cd.iloc[36:,:]

# %%
df['date'] = df["date"].dt.strftime("%m/%d/%y")
# Out:
# C:\Users\Anil Chowdary\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df1['date'] = df1['date'].dt.strftime("%d/%m/%y")
# Out:
# C:\Users\Anil Chowdary\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
a=pd.concat([df1, df] , axis = 0)

# %%
a.to_csv("E:/new1.csv")

# %%
data1 = pd.read_csv("E:/new1.csv")

# %%
data1
# Out:
#     Unnamed: 0  Cured  Deaths  Confirmed      date
# 0            0      0       0          2  02/01/20
# 1            1      0       0          3  03/01/20
# 2            2    144      41       1834  04/01/20
# 3            3      0       0          3  02/02/20
# 4            4      0       0          5  03/02/20
# 5            5    156      53       2069  04/02/20
# 6            6      0       0          3  02/03/20
# 7            7      3       0          6  03/03/20
# 8            8    163      62       2547  04/03/20
# 9            9      0       0          3  02/04/20
# 10          10      3       0         28  03/04/20
# 11          11    213      75       3072  04/04/20
# 12          12      0       0          3  02/05/20
# 13          13      3       0         30  03/05/20
# 14          14    275      83       3577  04/05/20
# 15          15      0       0          3  02/06/20
# 16          16      3       0         31  03/06/20
# ...

# %%
data1['date'] = pd.to_datetime(data1.date)

# %%
data1.sort_values(by ='date', inplace = True)

# %%
data1.to_csv("e:/DataSets/COVID_19_CLEANED.csv")
